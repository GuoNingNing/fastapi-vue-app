# %%
from utils.youtube import sniffing_video_info,get_best_video_info

url = "https://www.youtube.com/watch?v=wW3peA63EUA&t=17s"
cookies_path = "./storage/cookies.txt"
get_best_video_info(url, cookies_path)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wW3peA63EUA&t=17s
# [youtube] wW3peA63EUA: Downloading webpage
# [youtube] wW3peA63EUA: Downloading web creator player API JSON
# [youtube] wW3peA63EUA: Downloading mweb player API JSON
# {'title': '高音质Hi-Fi发烧CDV.A.-.[绝对发烧1].专辑',
#  'uploader': 'Hi-Fi发烧音乐',
#  'upload_date': '20230106',
#  'like_count': 5197,
#  'view_count': 669068,
#  'description': '高音质Hi-Fi发烧CDV.A.-.【绝对发烧1】.专辑\n   ↓↓↓【点下面时间选曲】\n【00:00:00】 - 01 如果雲知道\n【00:06:00】 - 02 最浪漫的事\n【00:11:01】 - 03 葬心\n【00:15:45】 - 04 在水一方\n【00:20:13】 - 05 胭脂扣\n【00:23:21】 - 06 此情可待\n【00:27:27】 - 07 心醉了\n【00:31:06】 - 08 情難枕\n【00:35:51】 - 09 假如我是真的\n【00:39:42】 - 10 月光下的鳳尾竹\n【00:45:16】 - 11 冰雨\n【00:49:43】 - 12 似水流年\n【00:54:31】 - 13 黃昏\n【00:59:21】 - 14 二月里來',
#  'subtitles': {},
# ...

# %%
df
# Out:
#    format_id format_note    ext protocol     acodec         vcodec  \
# 0        sb2  storyboard  mhtml    mhtml       none           none
# 1        sb1  storyboard  mhtml    mhtml       none           none
# 2        sb0  storyboard  mhtml    mhtml       none           none
# 3        599    ultralow    m4a    https  mp4a.40.5           none
# 4        600    ultralow   webm    https       opus           none
# 5        249         low   webm    https       opus           none
# 6        250         low   webm    https       opus           none
# 7        140      medium    m4a    https  mp4a.40.2           none
# 8        251      medium   webm    https       opus           none
# 9        597        144p    mp4    https       none    avc1.4d400b
# 10       598        144p   webm    https       none            vp9
# 11       160        144p    mp4    https       none    avc1.4d400c
# 12       278        144p   webm    https       none            vp9
# ...

# %%
df.loc[df['filesize'].idxmax()]['url']
# Out:
# 'https://rr2---sn-n4v7snl7.googlevideo.com/videoplayback?expire=1736170328&ei=-IZ7Z-a-MqHzsfIPn9y46A4&ip=23.95.165.57&id=o-APE6TUoNsuORYlnLJb_GZbEN0JUIe9N8hF2qMkJXZUbB&itag=248&aitags=133%2C134%2C135%2C136%2C137%2C160%2C242%2C243%2C244%2C247%2C248%2C278%2C394%2C395%2C396%2C397%2C398%2C399&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1736148728%2C&mh=jl&mm=31%2C26&mn=sn-n4v7snl7%2Csn-a5mekn6k&ms=au%2Conr&mv=m&mvi=2&pl=27&rms=au%2Cau&ctier=A&pfa=5&initcwndbps=1357500&hightc=yes&siu=1&bui=AfMhrI9ENokmxRSoLkbdIPpLBoXYW8uobw3pKvkQVS5tNEqglf-xgxq4070G6-JvPBFogw_GYA&spc=x-caUGMDtBldlvroydUIPZCiRZ2KOs2dbvWHmNQ9QZiRVc_t7svmXgJHAmMvEWo8bQ&vprv=1&svpuc=1&mime=video%2Fwebm&ns=4Q4-SyOzWwvlIlkZ5Zzrx68Q&rqh=1&gir=yes&clen=120665313&dur=3787.720&lmt=1726730302955569&mt=1736148288&fvip=4&keepalive=yes&fexp=51326932%2C51335594&c=WEB_CREATOR&sefc=1&txp=5437434&n=kmOl6ap15RcIEg&sparams=expire%2Cei%2Cip%2Cid%2Caitags%2Csource%2Crequiressl%2Cxpc%2Cctier%2Cpfa%2Chightc%2Csiu%2Cbui%2Cspc%2Cvprv%2C
# ...

# %%
df.loc[df[df['fps'].isna()]['filesize'].idxmax()]
# Out:
# format_id                                                            251
# format_note                                                       medium
# ext                                                                 webm
# protocol                                                           https
# acodec                                                              opus
# vcodec                                                              none
# url                    https://rr2---sn-n4v7snl7.googlevideo.com/vide...
# width                                                                NaN
# height                                                               NaN
# fps                                                                  NaN
# rows                                                                 NaN
# columns                                                              NaN
# fragments                                                            NaN
# ...

# %%
from utils.youtube import get_best_video_info

get_best_video_info(url, cookies_path)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wW3peA63EUA&t=17s
# [youtube] wW3peA63EUA: Downloading webpage
# [youtube] wW3peA63EUA: Downloading web creator player API JSON
# [youtube] wW3peA63EUA: Downloading mweb player API JSON
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from utils.youtube import get_best_video_info
# ----> 3 get_best_video_info(url, cookies_path)
#
# File ~/Workspace/fastapi-vue-app/backend/utils/youtube.py:60, in get_best_video_info(video_url, cookies_file)
#      58 best['description'] = dicts.get('description')
#      59 best['subtitles'] = dicts.get('subtitles', '无可用字幕')
# ---> 60 df = pd.DataFrame(dicts['formats'])
#      61 best['video'] = df.loc[df['filesize'].idxmax()]['url']
#      62 best['meda'] = df.loc[df[df['fps'].isna()]['filesize'].idxmax()]['url']
#
# NameError: name 'pd' is not defined
